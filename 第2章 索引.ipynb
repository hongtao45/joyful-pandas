# %% [markdown]
# # 第2章 索引

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('data/table.csv', index_col='ID')
df.head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 1101 to 2405
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   School   35 non-null     object
#  1   Class    35 non-null     object
#  2   Gender   35 non-null     object
#  3   Address  35 non-null     object
#  4   Height   35 non-null     int64
#  5   Weight   35 non-null     int64
#  6   Math     35 non-null     float64
#  7   Physics  35 non-null     object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 2.5+ KB

# %%
df.describe() # 会自己计算数值型的统计值
df["Gender"].describe() # 直接指定，就计算一些计算指标
# Out:
# count     35
# unique     2
# top        F
# freq      19
# Name: Gender, dtype: object

# %% [markdown]
# ## 一、单级索引
# ### 1. loc方法、iloc方法、[]操作符
# #### 最常用的索引方法可能就是这三类，其中iloc表示位置索引，loc表示标签索引，[]也具有很大的便利性，各有特点
# #### （a）loc方法
# #### ① 单行索引：

# %%
df.loc[1103] #! 只有一个位置时，优先默认行坐标
# Out:
# School          S_1
# Class           C_1
# Gender            M
# Address    street_2
# Height          186
# Weight           82
# Math           87.2
# Physics          B+
# Name: 1103, dtype: object

# %% [markdown]
# #### ② 多行索引：

# %%
idx = np.array([1102,2304])
df.loc[idx] # 多行时，第一个参数可以传list np.array
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 2304    S_2   C_3      F  street_6     164      81  95.5      A-

# %% [markdown]
# #### （注意：所有在loc中使用的切片全部包含右端点！这是因为如果作为Pandas的使用者，那么肯定不太关心最后一个标签再往后一位是什么，但是如果是左闭右开，那么就很麻烦，先要知道再后面一列的名字是什么，非常不方便，因此Pandas中将loc设计为左右全闭）

# %%
df.loc[np.arange(1101, 1103)] # 但是这个地方的numpy，自己肯定不包含最右边的一位的
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+

# %%
df.index
# Out:
# Int64Index([1101, 1102, 1103, 1104, 1105, 1201, 1202, 1203, 1204, 1205, 1301,
#             1302, 1303, 1304, 1305, 2101, 2102, 2103, 2104, 2105, 2201, 2202,
#             2203, 2204, 2205, 2301, 2302, 2303, 2304, 2305, 2401, 2402, 2403,
#             2404, 2405],
#            dtype='int64', name='ID')

# %%
df.loc[1304:2103].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1304    S_1   C_3      M  street_2     195      70  85.2       A
# 1305    S_1   C_3      F  street_5     187      69  61.7      B-
# 2101    S_2   C_1      M  street_7     174      84  83.3       C
# 2102    S_2   C_1      F  street_6     161      61  50.6      B+
# 2103    S_2   C_1      M  street_4     157      61  52.5      B-

# %%
list(range(5,0,-1))
# Out:
# [5, 4, 3, 2, 1]

# %%
df.loc[2402::-1].head() # 从某一个位置往回全部都索引
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 2402    S_2   C_4      M  street_7     166      82  48.7       B
# 2401    S_2   C_4      F  street_2     192      62  45.3       A
# 2305    S_2   C_3      M  street_4     187      73  48.9       B
# 2304    S_2   C_3      F  street_6     164      81  95.5      A-
# 2303    S_2   C_3      F  street_7     190      99  65.9       C

# %% [markdown]
# #### ③ 单列索引：

# %%
df.loc[:,'Height'].head() #全部行，行就用：站位
# Out:
# ID
# 1101    173
# 1102    192
# 1103    186
# 1104    167
# 1105    159
# Name: Height, dtype: int64

# %% [markdown]
# #### ④ 多列索引：

# %%
df.loc[:,['Height','Math']].head()
# Out:
#       Height  Math
# ID
# 1101     173  34.0
# 1102     192  32.5
# 1103     186  87.2
# 1104     167  80.4
# 1105     159  84.8

# %%
df.columns
# Out:
# Index(['School', 'Class', 'Gender', 'Address', 'Height', 'Weight', 'Math',
#        'Physics'],
#       dtype='object')

# %%
df.loc[:,'Height':'Math'].head() # 前后两列之间的数据，全部列， 也可以用分号
# Out:
#       Height  Weight  Math
# ID
# 1101     173      63  34.0
# 1102     192      73  32.5
# 1103     186      82  87.2
# 1104     167      81  80.4
# 1105     159      64  84.8

# %% [markdown]
# #### ⑤ 联合索引：

# %%
df.loc[1102:2401:3,'Height':'Math'].head()
# Out:
#       Height  Weight  Math
# ID
# 1102     192      73  32.5
# 1105     159      64  84.8
# 1203     160      53  58.8
# 1301     161      68  31.5
# 1304     195      70  85.2

# %%
df.loc[1102:2401:3,['Height':'Math']].head() # [] 没有这种写法
# Out:
#   File "C:\Users\hongtao45\AppData\Local\Temp\ipykernel_11540\2351374039.py", line 1
#     df.loc[1102:2401:3,['Height':'Math']].head() # [] 没有这种写法
#                                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### ⑥ 函数式索引：

# %%
df.loc[lambda x: x['Gender']=='M'].head()
# loc中使用的函数，传入参数就是前面的df
# 每一行的数据作为输入x
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1201    S_1   C_2      M  street_5     188      68  97.0      A-
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+

# %%
#这里的例子表示，loc中能够传入函数，并且函数的输入值是整张表，输出为标量、切片、合法列表（元素出现在索引中）、合法索引
def f(x):
    return [1101,1103]
df.loc[f]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+

# %% [markdown]
# #### ⑦ 布尔索引（将重点在第2节介绍）

# %%
bl = df["Address"].isin(['street_7','street_4']) # 作用到一列
print(1)
# Out:
# 1

# %%
df.loc[df['Address'].isin(['street_7','street_4'])].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+
# 1202    S_1   C_2      F  street_4     176      94  63.5      B-
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+
# 1303    S_1   C_3      M  street_7     188      82  49.7       B
# 2101    S_2   C_1      M  street_7     174      84  83.3       C

# %%
df["Address"].values
# Out:
# array(['street_1', 'street_2', 'street_2', 'street_2', 'street_4',
#        'street_5', 'street_4', 'street_6', 'street_5', 'street_6',
#        'street_4', 'street_1', 'street_7', 'street_2', 'street_5',
#        'street_7', 'street_6', 'street_4', 'street_5', 'street_4',
#        'street_5', 'street_7', 'street_4', 'street_1', 'street_7',
#        'street_4', 'street_5', 'street_7', 'street_6', 'street_4',
#        'street_2', 'street_7', 'street_6', 'street_2', 'street_6'],
#       dtype=object)

# %%
df.loc[[True if i[-1]=='4' or i[-1]=='7' else False for i in df['Address'].values]].head()

# bool 索引
# 一行for循环
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+
# 1202    S_1   C_2      F  street_4     176      94  63.5      B-
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+
# 1303    S_1   C_3      M  street_7     188      82  49.7       B
# 2101    S_2   C_1      M  street_7     174      84  83.3       C

# %% [markdown]
# #### 小节：本质上说，loc中能传入的只有布尔列表和索引子集构成的列表，只要把握这个原则就很容易理解上面那些操作
# #### （b）iloc方法（注意与loc不同，切片右端点不包含）
# #### ① 单行索引：

# %%
df.iloc[3] #iloc用的数字位置的坐标来切片
# Out:
# School          S_1
# Class           C_1
# Gender            F
# Address    street_2
# Height          167
# Weight           81
# Math           80.4
# Physics          B-
# Name: 1104, dtype: object

# %% [markdown]
# #### ② 多行索引：

# %%
df.iloc[3:5] # 不包含右端点
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### ③ 单列索引：

# %%
df.iloc[:,3].head()
# Out:
# ID
# 1101    street_1
# 1102    street_2
# 1103    street_2
# 1104    street_2
# 1105    street_4
# Name: Address, dtype: object

# %%
df.iloc[:, :3].head()
# Out:
#      School Class Gender
# ID
# 1101    S_1   C_1      M
# 1102    S_1   C_1      F
# 1103    S_1   C_1      M
# 1104    S_1   C_1      F
# 1105    S_1   C_1      F

# %% [markdown]
# #### ④ 多列索引：

# %%
df.iloc[:,7::-2].head()
# Out:
#      Physics  Weight   Address Class
# ID
# 1101      A+      63  street_1   C_1
# 1102      B+      73  street_2   C_1
# 1103      B+      82  street_2   C_1
# 1104      B-      81  street_2   C_1
# 1105      B+      64  street_4   C_1

# %% [markdown]
# #### ⑤ 混合索引：

# %%
df.iloc[3::4,7::-2].head()
# Out:
#      Physics  Weight   Address Class
# ID
# 1104      B-      81  street_2   C_1
# 1203      A+      53  street_6   C_2
# 1302      A-      57  street_1   C_3
# 2101       C      84  street_7   C_1
# 2105       A      81  street_4   C_1

# %% [markdown]
# #### ⑥ 函数式索引：

# %%
df.iloc[lambda x:[0]].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+

# %% [markdown]
# #### 小节：iloc中接收的参数只能为整数或整数列表或布尔列表，不能使用布尔Series，如果要用就必须如下把values拿出来

# %%
#df.iloc[df['School']=='S_1'].head() #报错
df.iloc[(df['School']=='S_1').values].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### （c） []操作符
# #### （c.1）Series的[]操作
# #### ① 单元素索引：

# %%
s = pd.Series(df['Math'],index=df.index)
s[1101]
# 使用的是索引标签
# Out:
# 34.0

# %% [markdown]
# #### ② 多行索引：

# %%
s[0:4]
#使用的是绝对位置的整数切片，与元素无关，这里容易混淆
# Out:
# ID
# 1101    34.0
# 1102    32.5
# 1103    87.2
# 1104    80.4
# Name: Math, dtype: float64

# %% [markdown]
# #### ③ 函数式索引：

# %%
s[lambda x: x.index[16::-6]]
#注意使用lambda函数时，直接切片(如：s[lambda x: 16::-6])就报错，此时使用的不是绝对位置切片，而是元素切片，非常易错
# Out:
# ID
# 2102    50.6
# 1301    31.5
# 1105    84.8
# Name: Math, dtype: float64

# %% [markdown]
# #### ④ 布尔索引：

# %%
s[s>80]
# Out:
# ID
# 1103    87.2
# 1104    80.4
# 1105    84.8
# 1201    97.0
# 1302    87.7
# 1304    85.2
# 2101    83.3
# 2205    85.4
# 2304    95.5
# Name: Math, dtype: float64

# %% [markdown]
# #### 【注意】如果不想陷入困境，请不要在行索引为浮点时使用[]操作符，因为在Series中[]的浮点切片并不是进行位置比较，而是值比较，非常特殊

# %%
s_int = pd.Series([1,2,3,4],index=[1,3,5,6])
s_float = pd.Series([1,2,3,4],index=[1.,3.,5.,6.])
s_int
# Out:
# 1    1
# 3    2
# 5    3
# 6    4
# dtype: int64

# %%
s_int[2:]
# Out:
# 5    3
# 6    4
# dtype: int64

# %%
s_float
# Out:
# 1.0    1
# 3.0    2
# 5.0    3
# 6.0    4
# dtype: int64

# %%
#注意和s_int[2:]结果不一样了，因为2这里是元素而不是位置
s_float[2:]
# Out:
# 3.0    2
# 5.0    3
# 6.0    4
# dtype: int64

# %% [markdown]
# #### （c.2）DataFrame的[]操作
# #### ① 单行索引：

# %%
df[1:2]
#这里非常容易写成df['label']，会报错
#同Series使用了绝对位置切片
#如果想要获得某一个元素，可用如下get_loc方法：
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+

# %%
row = df.index.get_loc(1102)
df[row:row+1]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+

# %%
row
# Out:
# 1

# %% [markdown]
# #### ② 多行索引：

# %%
#用切片，如果是选取指定的某几行，推荐使用loc，否则很可能报错
df[3:5]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %%
df.iloc[3:5]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### ③ 单列索引：

# %%
df['School'].head()
# Out:
# ID
# 1101    S_1
# 1102    S_1
# 1103    S_1
# 1104    S_1
# 1105    S_1
# Name: School, dtype: object

# %% [markdown]
# #### ④ 多列索引：

# %%
df[['School','Math']].head()
# Out:
#      School  Math
# ID
# 1101    S_1  34.0
# 1102    S_1  32.5
# 1103    S_1  87.2
# 1104    S_1  80.4
# 1105    S_1  84.8

# %% [markdown]
# #### ⑤函数式索引：

# %%
df[lambda x:['Math','Physics']].head()
# Out:
#       Math Physics
# ID
# 1101  34.0      A+
# 1102  32.5      B+
# 1103  87.2      B+
# 1104  80.4      B-
# 1105  84.8      B+

# %% [markdown]
# #### ⑥ 布尔索引：

# %%
df[df['Gender']=='F'].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+
# 1202    S_1   C_2      F  street_4     176      94  63.5      B-
# 1204    S_1   C_2      F  street_5     162      63  33.8       B

# %% [markdown]
# #### 小节：一般来说，[]操作符常用于列选择或布尔选择，尽量避免行的选择
# ### 2. 布尔索引
# #### （a）布尔符号：'&','|','~'：分别代表和and，或or，取反not

# %%
df[(df['Gender']=='F')&(df['Address']=='street_2')].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 2401    S_2   C_4      F  street_2     192      62  45.3       A
# 2404    S_2   C_4      F  street_2     160      84  67.7       B

# %%
df[(df['Math']>85)|(df['Address']=='street_7')].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1201    S_1   C_2      M  street_5     188      68  97.0      A-
# 1302    S_1   C_3      F  street_1     175      57  87.7      A-
# 1303    S_1   C_3      M  street_7     188      82  49.7       B
# 1304    S_1   C_3      M  street_2     195      70  85.2       A

# %%
df[~((df['Math']>75)|(df['Address']=='street_1'))].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1202    S_1   C_2      F  street_4     176      94  63.5      B-
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1204    S_1   C_2      F  street_5     162      63  33.8       B
# 1205    S_1   C_2      F  street_6     167      63  68.4      B-

# %% [markdown]
# #### loc和[]中相应位置都能使用布尔列表选择：

# %%
df.loc[df['Math']>60,df.columns=='Physics'].head()
#思考：为什么df.loc[df['Math']>60,(df[:8]['Address']=='street_6').values].head()得到和上述结果一样？values能去掉吗？
# Out:
#      Physics
# ID
# 1103      B+
# 1104      B-
# 1105      B+
# 1201      A-
# 1202      B-

# %% [markdown]
# #### （b） isin方法

# %%
df[df['Address'].isin(['street_1','street_4'])&df['Physics'].isin(['A','A+'])]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 2105    S_2   C_1      M  street_4     170      81  34.2       A
# 2203    S_2   C_2      M  street_4     155      91  73.8      A+

# %%
#上面也可以用字典方式写：
df[df[['Address','Physics']].isin({'Address':['street_1','street_4'],'Physics':['A','A+']}).all(1)]
#all与&的思路是类似的，其中的1代表按照跨列方向判断是否全为True
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 2105    S_2   C_1      M  street_4     170      81  34.2       A
# 2203    S_2   C_2      M  street_4     155      91  73.8      A+

# %% [markdown]
# ### 3. 快速标量索引
# #### 当只需要取一个元素时，at和iat方法能够提供更快的实现：

# %%
display(df.at[1101,'School'])
display(df.loc[1101,'School'])
display(df.iat[0,0])
display(df.iloc[0,0])
#可尝试去掉注释对比时间
# %timeit df.at[1101,'School']
# %timeit df.loc[1101,'School']
# %timeit df.iat[0,0]
# %timeit df.iloc[0,0]
# Out:
# 'S_1'
# 'S_1'
# 'S_1'
# 'S_1'
# 2.16 µs ± 46.4 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 4.35 µs ± 18.8 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 11.2 µs ± 48.3 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 13.5 µs ± 48 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# ### 4. 区间索引
# #### 此处介绍并不是说只能在单级索引中使用区间索引，只是作为一种特殊类型的索引方式，在此处先行介绍
# #### （a）利用interval_range方法

# %%
pd.interval_range(start=0,end=5)
#closed参数可选'left''right''both''neither'，默认左开右闭
# Out:
# IntervalIndex([(0, 1], (1, 2], (2, 3], (3, 4], (4, 5]], dtype='interval[int64, right]')

# %%
pd.interval_range(start=pd.Timestamp("2022/05/10"), end=pd.Timestamp("2022/05/20"), periods=10)
# Out:
# IntervalIndex([(2022-05-10, 2022-05-11], (2022-05-11, 2022-05-12], (2022-05-12, 2022-05-13], (2022-05-13, 2022-05-14], (2022-05-14, 2022-05-15], (2022-05-15, 2022-05-16], (2022-05-16, 2022-05-17], (2022-05-17, 2022-05-18], (2022-05-18, 2022-05-19], (2022-05-19, 2022-05-20]], dtype='interval[datetime64[ns], right]')

# %%
pd.interval_range(start=0,periods=8,freq=5)
#periods参数控制区间个数，freq控制步长
# Out:
# IntervalIndex([(0, 5], (5, 10], (10, 15], (15, 20], (20, 25], (25, 30], (30, 35], (35, 40]], dtype='interval[int64, right]')

# %% [markdown]
# #### （b）利用cut将数值列转为区间为元素的分类变量，例如统计数学成绩的区间情况：

# %%
math_interval = pd.cut(df['Math'], bins=[0,40,60,80,100])
#注意，如果没有类型转换，此时并不是区间类型，而是category类型
math_interval.head()
# Out:
# ID
# 1101      (0, 40]
# 1102      (0, 40]
# 1103    (80, 100]
# 1104    (80, 100]
# 1105    (80, 100]
# Name: Math, dtype: category
# Categories (4, interval[int64, right]): [(0, 40] < (40, 60] < (60, 80] < (80, 100]]

# %% [markdown]
# #### （c）区间索引的选取

# %%
# 分解
df_i = df.join(math_interval, rsuffix='_interval')
df_i = df_i[['Math','Math_interval']]
df_i.reset_index(drop=True, inplace=True)
df_i.set_index("Math_interval")
df_i.head()
# Out:
#    Math Math_interval
# 0  34.0       (0, 40]
# 1  32.5       (0, 40]
# 2  87.2     (80, 100]
# 3  80.4     (80, 100]
# 4  84.8     (80, 100]

# %%
df_i = df.join(math_interval, rsuffix='_interval')[['Math','Math_interval']]\
            .reset_index().set_index('Math_interval')
df_i.head()
# Out:
#                  ID  Math
# Math_interval
# (0, 40]        1101  34.0
# (0, 40]        1102  32.5
# (80, 100]      1103  87.2
# (80, 100]      1104  80.4
# (80, 100]      1105  84.8

# %%
df_i.loc[65].head()
#包含该值就会被选中
# Out:
#                  ID  Math
# Math_interval
# (60, 80]       1202  63.5
# (60, 80]       1205  68.4
# (60, 80]       1305  61.7
# (60, 80]       2104  72.2
# (60, 80]       2202  68.5

# %%
df_i.loc[[65,90]].head(10)
# Out:
#                  ID  Math
# Math_interval
# (60, 80]       1202  63.5
# (60, 80]       1205  68.4
# (60, 80]       1305  61.7
# (60, 80]       2104  72.2
# (60, 80]       2202  68.5
# (60, 80]       2203  73.8
# (60, 80]       2301  72.3
# (60, 80]       2303  65.9
# (60, 80]       2404  67.7
# (80, 100]      1103  87.2

# %% [markdown]
# #### 如果想要选取某个区间，先要把分类变量转为区间变量，再使用overlap方法：

# %%
#df_i.loc[pd.Interval(70,75)].head() 报错
df_i[df_i.index.astype('interval').overlaps(pd.Interval(70, 85))].head()
# Out:
#                  ID  Math
# Math_interval
# (80, 100]      1103  87.2
# (80, 100]      1104  80.4
# (80, 100]      1105  84.8
# (80, 100]      1201  97.0
# (60, 80]       1202  63.5

# %% [markdown]
# ## 二、多级索引
# ### 1. 创建多级索引
# #### （a）通过from_tuple或from_arrays
# #### ① 直接创建元组

# %%
tuples = [('A','a'),('A','b'),('B','a'),('B','b')]
mul_index = pd.MultiIndex.from_tuples(tuples, names=('Upper', 'Lower'))
mul_index
# Out:
# MultiIndex([('A', 'a'),
#             ('A', 'b'),
#             ('B', 'a'),
#             ('B', 'b')],
#            names=['Upper', 'Lower'])

# %%
pd.DataFrame({'Score':['perfect','good','fair','bad']},index=mul_index)
# Out:
#                Score
# Upper Lower
# A     a      perfect
#       b         good
# B     a         fair
#       b          bad

# %% [markdown]
# #### ② 利用zip创建元组

# %%
L1 = list('AABB')
L2 = list('abab')
tuples = list(zip(L1,L2))
mul_index = pd.MultiIndex.from_tuples(tuples, names=('Upper', 'Lower'))
pd.DataFrame({'Score':['perfect','good','fair','bad']},index=mul_index)
# Out:
#                Score
# Upper Lower
# A     a      perfect
#       b         good
# B     a         fair
#       b          bad

# %% [markdown]
# #### ③ 通过Array创建

# %%
arrays = [['A','a'],['A','b'],['B','a'],['B','b']]
mul_index = pd.MultiIndex.from_tuples(arrays, names=('Upper', 'Lower'))
pd.DataFrame({'Score':['perfect','good','fair','bad']},index=mul_index)
# Out:
#                Score
# Upper Lower
# A     a      perfect
#       b         good
# B     a         fair
#       b          bad

# %%
mul_index
#由此看出内部自动转成元组
# Out:
# MultiIndex([('A', 'a'),
#             ('A', 'b'),
#             ('B', 'a'),
#             ('B', 'b')],
#            names=['Upper', 'Lower'])

# %% [markdown]
# #### （b）通过from_product

# %%
L1 = ['A','B']
L2 = ['a','b']
pd.MultiIndex.from_product([L1,L2],names=('Upper', 'Lower'))
#两两相乘
# Out:
# MultiIndex([('A', 'a'),
#             ('A', 'b'),
#             ('B', 'a'),
#             ('B', 'b')],
#            names=['Upper', 'Lower'])

# %% [markdown]
# #### （c）指定df中的列创建（set_index方法）

# %%
df_using_mul = df.set_index(['Class','Address'])
df_using_mul.head()
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_1   street_1    S_1      M     173      63  34.0      A+
#       street_2    S_1      F     192      73  32.5      B+
#       street_2    S_1      M     186      82  87.2      B+
#       street_2    S_1      F     167      81  80.4      B-
#       street_4    S_1      F     159      64  84.8      B+

# %% [markdown]
# ### 2. 多层索引切片

# %%
df_using_mul.head()
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_1   street_1    S_1      M     173      63  34.0      A+
#       street_2    S_1      F     192      73  32.5      B+
#       street_2    S_1      M     186      82  87.2      B+
#       street_2    S_1      F     167      81  80.4      B-
#       street_4    S_1      F     159      64  84.8      B+

# %% [markdown]
# #### （a）一般切片

# %%
# df_using_mul.loc['C_2','street_5']
#当索引不排序时，单个索引会报出性能警告
# df_using_mul.index.is_lexsorted()
#该函数检查是否排序
df_using_mul.sort_index().loc['C_2','street_5']
# df_using_mul.sort_index().index.is_lexsorted()
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_2   street_5    S_1      M     188      68  97.0      A-
#       street_5    S_1      F     162      63  33.8       B
#       street_5    S_2      M     193     100  39.1       B

# %%
#df_using_mul.loc[('C_2','street_5'):] 报错
#当不排序时，不能使用多层切片
df_using_mul.sort_index().loc[('C_2','street_6'):('C_3','street_4')]
#注意此处由于使用了loc，因此仍然包含右端点
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_2   street_6    S_1      M     160      53  58.8      A+
#       street_6    S_1      F     167      63  68.4      B-
#       street_7    S_2      F     194      77  68.5      B+
#       street_7    S_2      F     183      76  85.4       B
# C_3   street_1    S_1      F     175      57  87.7      A-
#       street_2    S_1      M     195      70  85.2       A
#       street_4    S_1      M     161      68  31.5      B+
#       street_4    S_2      F     157      78  72.3      B+
#       street_4    S_2      M     187      73  48.9       B

# %%
df_using_mul.sort_index().loc[('C_2','street_7'):'C_3'].head()
#非元组也是合法的，表示选中该层所有元素
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_2   street_7    S_2      F     194      77  68.5      B+
#       street_7    S_2      F     183      76  85.4       B
# C_3   street_1    S_1      F     175      57  87.7      A-
#       street_2    S_1      M     195      70  85.2       A
#       street_4    S_1      M     161      68  31.5      B+

# %% [markdown]
# #### （b）第一类特殊情况：由元组构成列表

# %%
df_using_mul.sort_index().loc[[('C_2','street_7'),('C_3','street_2')]]
#表示选出某几个元素，精确到最内层索引
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_2   street_7    S_2      F     194      77  68.5      B+
#       street_7    S_2      F     183      76  85.4       B
# C_3   street_2    S_1      M     195      70  85.2       A

# %% [markdown]
# #### （c）第二类特殊情况：由列表构成元组

# %%
df_using_mul.sort_index().loc[(['C_2','C_3'],['street_4','street_7']),:]
#选出第一层在‘C_2’和'C_3'中且第二层在'street_4'和'street_7'中的行
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_2   street_4    S_1      F     176      94  63.5      B-
#       street_4    S_2      M     155      91  73.8      A+
#       street_7    S_2      F     194      77  68.5      B+
#       street_7    S_2      F     183      76  85.4       B
# C_3   street_4    S_1      M     161      68  31.5      B+
#       street_4    S_2      F     157      78  72.3      B+
#       street_4    S_2      M     187      73  48.9       B
#       street_7    S_1      M     188      82  49.7       B
#       street_7    S_2      F     190      99  65.9       C

# %% [markdown]
# ### 3. 多层索引中的slice对象

# %%
L1,L2 = ['A','B','C'],['a','b','c']
mul_index1 = pd.MultiIndex.from_product([L1,L2],names=('Upper', 'Lower'))
L3,L4 = ['D','E','F'],['d','e','f']
mul_index2 = pd.MultiIndex.from_product([L3,L4],names=('Big', 'Small'))
df_s = pd.DataFrame(np.random.rand(9,9),index=mul_index1,columns=mul_index2)
df_s
# Out:
# Big                 D                             E                      \
# Small               d         e         f         d         e         f
# Upper Lower
# A     a      0.332231  0.812168  0.927344  0.364812  0.203047  0.642874
#       b      0.617956  0.727173  0.158200  0.059368  0.244104  0.011844
#       c      0.972723  0.950801  0.011401  0.364135  0.557138  0.679273
# B     a      0.630500  0.774539  0.315887  0.783191  0.816552  0.527002
#       b      0.803929  0.682831  0.247802  0.626485  0.440538  0.105715
#       c      0.260209  0.177072  0.934890  0.331660  0.825246  0.571255
# C     a      0.438169  0.404519  0.227383  0.318176  0.349797  0.440333
#       b      0.400395  0.632796  0.637319  0.253866  0.747759  0.565288
#       c      0.475739  0.823388  0.092965  0.092214  0.843514  0.025870
#
# Big                 F
# Small               d         e         f
# Upper Lower
# A     a      0.779462  0.643944  0.006103
#       b      0.475175  0.004620  0.091784
#       c      0.516068  0.219058  0.565332
# B     a      0.915802  0.076262  0.996702
#       b      0.712884  0.796893  0.516483
#       c      0.473664  0.721910  0.921324
# C     a      0.393500  0.337937  0.823046
#       b      0.480005  0.866698  0.636872
#       c      0.700339  0.501077  0.652040

# %%
idx=pd.IndexSlice

# %% [markdown]
# #### 索引Slice的使用非常灵活：

# %%
df_s.loc[idx['B':,df_s['D']['d']>0.3],idx[df_s.sum()>4]]
#df_s.sum()默认为对列求和，因此返回一个长度为9的数值列表
# Out:
# Big                 D                   E         F
# Small               d         e         e         d         e         f
# Upper Lower
# B     a      0.630500  0.774539  0.816552  0.915802  0.076262  0.996702
#       b      0.803929  0.682831  0.440538  0.712884  0.796893  0.516483
# C     a      0.438169  0.404519  0.349797  0.393500  0.337937  0.823046
#       b      0.400395  0.632796  0.747759  0.480005  0.866698  0.636872
#       c      0.475739  0.823388  0.843514  0.700339  0.501077  0.652040

# %% [markdown]
# ### 4. 索引层的交换
# #### （a）swaplevel方法（两层交换）

# %%
df_using_mul.head()
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_1   street_1    S_1      M     173      63  34.0      A+
#       street_2    S_1      F     192      73  32.5      B+
#       street_2    S_1      M     186      82  87.2      B+
#       street_2    S_1      F     167      81  80.4      B-
#       street_4    S_1      F     159      64  84.8      B+

# %%
df_using_mul.swaplevel(i=1,j=0,axis=0).sort_index().head()
# Out:
#                School Gender  Height  Weight  Math Physics
# Address  Class
# street_1 C_1      S_1      M     173      63  34.0      A+
#          C_2      S_2      M     175      74  47.2      B-
#          C_3      S_1      F     175      57  87.7      A-
# street_2 C_1      S_1      F     192      73  32.5      B+
#          C_1      S_1      M     186      82  87.2      B+

# %% [markdown]
# #### （b）reorder_levels方法（多层交换）

# %%
df_muls = df.set_index(['School','Class','Address'])
df_muls.head()
# Out:
#                       Gender  Height  Weight  Math Physics
# School Class Address
# S_1    C_1   street_1      M     173      63  34.0      A+
#              street_2      F     192      73  32.5      B+
#              street_2      M     186      82  87.2      B+
#              street_2      F     167      81  80.4      B-
#              street_4      F     159      64  84.8      B+

# %%
df_muls.reorder_levels([2,0,1],axis=0).sort_index().head()
# Out:
#                       Gender  Height  Weight  Math Physics
# Address  School Class
# street_1 S_1    C_1        M     173      63  34.0      A+
#                 C_3        F     175      57  87.7      A-
#          S_2    C_2        M     175      74  47.2      B-
# street_2 S_1    C_1        F     192      73  32.5      B+
#                 C_1        M     186      82  87.2      B+

# %%
#如果索引有name，可以直接使用name
df_muls.reorder_levels(['Address','School','Class'],axis=0).sort_index().head()
# Out:
#                       Gender  Height  Weight  Math Physics
# Address  School Class
# street_1 S_1    C_1        M     173      63  34.0      A+
#                 C_3        F     175      57  87.7      A-
#          S_2    C_2        M     175      74  47.2      B-
# street_2 S_1    C_1        F     192      73  32.5      B+
#                 C_1        M     186      82  87.2      B+

# %% [markdown]
# ## 三、索引设定
# ### 1. index_col参数
# #### index_col是read_csv中的一个参数，而不是某一个方法：

# %%
pd.read_csv('data/table.csv',index_col=['Address','School']).head()
# Out:
#                 Class    ID Gender  Height  Weight  Math Physics
# Address  School
# street_1 S_1      C_1  1101      M     173      63  34.0      A+
# street_2 S_1      C_1  1102      F     192      73  32.5      B+
#          S_1      C_1  1103      M     186      82  87.2      B+
#          S_1      C_1  1104      F     167      81  80.4      B-
# street_4 S_1      C_1  1105      F     159      64  84.8      B+

# %% [markdown]
# ### 2. reindex和reindex_like
# #### reindex是指重新索引，它的重要特性在于索引对齐，很多时候用于重新排序

# %%
df.head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %%
df.reindex(index=[1101,1203,1206,2402])
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1   173.0    63.0  34.0      A+
# 1203    S_1   C_2      M  street_6   160.0    53.0  58.8      A+
# 1206    NaN   NaN    NaN       NaN     NaN     NaN   NaN     NaN
# 2402    S_2   C_4      M  street_7   166.0    82.0  48.7       B

# %%
df.reindex(columns=['Height','Gender','Average']).head()
# Out:
#       Height Gender  Average
# ID
# 1101     173      M      NaN
# 1102     192      F      NaN
# 1103     186      M      NaN
# 1104     167      F      NaN
# 1105     159      F      NaN

# %% [markdown]
# #### 可以选择缺失值的填充方法：fill_value和method（bfill/ffill/nearest），其中method参数必须索引单调

# %%
df.reindex(index=[1101,1203,1206,2402],method='bfill')
#bfill表示用所在索引1206的后一个有效行填充，ffill为前一个有效行，nearest是指最近的
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1206    S_1   C_3      M  street_4     161      68  31.5      B+
# 2402    S_2   C_4      M  street_7     166      82  48.7       B

# %%
df.reindex(index=[1101,1203,1206,2402],method='nearest')
#数值上1205比1301更接近1206，因此用前者填充
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1206    S_1   C_2      F  street_6     167      63  68.4      B-
# 2402    S_2   C_4      M  street_7     166      82  48.7       B

# %% [markdown]
# #### reindex_like的作用为生成一个横纵索引完全与参数列表一致的DataFrame，数据使用被调用的表

# %%
df_temp = pd.DataFrame({'Weight':np.zeros(5),
                        'Height':np.zeros(5),
                        'ID':[1101,1104,1103,1106,1102]}).set_index('ID')
df_temp.reindex_like(df[0:5][['Weight','Height']])
# Out:
#       Weight  Height
# ID
# 1101     0.0     0.0
# 1102     0.0     0.0
# 1103     0.0     0.0
# 1104     0.0     0.0
# 1105     NaN     NaN

# %% [markdown]
# #### 如果df_temp单调还可以使用method参数：

# %%
df_temp = pd.DataFrame({'Weight':range(5),
                        'Height':range(5),
                        'ID':[1101,1104,1103,1106,1102]}).set_index('ID').sort_index()
df_temp.reindex_like(df[0:5][['Weight','Height']],method='bfill')
#可以自行检验这里的1105的值是否是由bfill规则填充
# Out:
#       Weight  Height
# ID
# 1101       0       0
# 1102       4       4
# 1103       2       2
# 1104       1       1
# 1105       3       3

# %% [markdown]
# ### 3. set_index和reset_index
# #### 先介绍set_index：从字面意思看，就是将某些列作为索引

# %% [markdown]
# #### 使用表内列作为索引：

# %%
df.head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %%
df.set_index('Class').head()
# Out:
#       School Gender   Address  Height  Weight  Math Physics
# Class
# C_1      S_1      M  street_1     173      63  34.0      A+
# C_1      S_1      F  street_2     192      73  32.5      B+
# C_1      S_1      M  street_2     186      82  87.2      B+
# C_1      S_1      F  street_2     167      81  80.4      B-
# C_1      S_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### 利用append参数可以将当前索引维持不变

# %%
df.set_index('Class',append=True).head()
# Out:
#            School Gender   Address  Height  Weight  Math Physics
# ID   Class
# 1101 C_1      S_1      M  street_1     173      63  34.0      A+
# 1102 C_1      S_1      F  street_2     192      73  32.5      B+
# 1103 C_1      S_1      M  street_2     186      82  87.2      B+
# 1104 C_1      S_1      F  street_2     167      81  80.4      B-
# 1105 C_1      S_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### 当使用与表长相同的列作为索引（需要先转化为Series，否则报错）：

# %%
df.set_index(pd.Series(range(df.shape[0]))).head()
# Out:
#   School Class Gender   Address  Height  Weight  Math Physics
# 0    S_1   C_1      M  street_1     173      63  34.0      A+
# 1    S_1   C_1      F  street_2     192      73  32.5      B+
# 2    S_1   C_1      M  street_2     186      82  87.2      B+
# 3    S_1   C_1      F  street_2     167      81  80.4      B-
# 4    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### 可以直接添加多级索引：

# %%
df.set_index([pd.Series(range(df.shape[0])),pd.Series(np.ones(df.shape[0]))]).head()
# Out:
#       School Class Gender   Address  Height  Weight  Math Physics
# 0 1.0    S_1   C_1      M  street_1     173      63  34.0      A+
# 1 1.0    S_1   C_1      F  street_2     192      73  32.5      B+
# 2 1.0    S_1   C_1      M  street_2     186      82  87.2      B+
# 3 1.0    S_1   C_1      F  street_2     167      81  80.4      B-
# 4 1.0    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### 下面介绍reset_index方法，它的主要功能是将索引重置
# #### 默认状态直接恢复到自然数索引：

# %%
df.reset_index().head()
# Out:
#      ID School Class Gender   Address  Height  Weight  Math Physics
# 0  1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1  1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 2  1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 3  1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 4  1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### 用level参数指定哪一层被reset，用col_level参数指定set到哪一层：

# %%
L1,L2 = ['A','B','C'],['a','b','c']
mul_index1 = pd.MultiIndex.from_product([L1,L2],names=('Upper', 'Lower'))
L3,L4 = ['D','E','F'],['d','e','f']
mul_index2 = pd.MultiIndex.from_product([L3,L4],names=('Big', 'Small'))
df_temp = pd.DataFrame(np.random.rand(9,9),index=mul_index1,columns=mul_index2)
df_temp.head()
# Out:
# Big                 D                             E                      \
# Small               d         e         f         d         e         f
# Upper Lower
# A     a      0.322822  0.543179  0.967577  0.888449  0.899564  0.002650
#       b      0.974375  0.433716  0.357654  0.989018  0.389088  0.938990
#       c      0.000210  0.910771  0.786087  0.869291  0.078134  0.251015
# B     a      0.517882  0.447018  0.218146  0.757236  0.887024  0.377133
#       b      0.126310  0.585848  0.060513  0.404525  0.402775  0.002464
#
# Big                 F
# Small               d         e         f
# Upper Lower
# A     a      0.299921  0.872671  0.268278
#       b      0.905009  0.473362  0.693009
#       c      0.788266  0.707512  0.821467
# B     a      0.004297  0.919222  0.393171
#       b      0.833294  0.619312  0.174691

# %%
df_temp1 = df_temp.reset_index(level=1,col_level=1)
df_temp1.head()
# Out:
# Big                 D                             E                      \
# Small Lower         d         e         f         d         e         f
# Upper
# A         a  0.322822  0.543179  0.967577  0.888449  0.899564  0.002650
# A         b  0.974375  0.433716  0.357654  0.989018  0.389088  0.938990
# A         c  0.000210  0.910771  0.786087  0.869291  0.078134  0.251015
# B         a  0.517882  0.447018  0.218146  0.757236  0.887024  0.377133
# B         b  0.126310  0.585848  0.060513  0.404525  0.402775  0.002464
#
# Big           F
# Small         d         e         f
# Upper
# A      0.299921  0.872671  0.268278
# A      0.905009  0.473362  0.693009
# A      0.788266  0.707512  0.821467
# B      0.004297  0.919222  0.393171
# B      0.833294  0.619312  0.174691

# %%
df_temp1.columns
#看到的确插入了level2
# Out:
# MultiIndex([( '', 'Lower'),
#             ('D',     'd'),
#             ('D',     'e'),
#             ('D',     'f'),
#             ('E',     'd'),
#             ('E',     'e'),
#             ('E',     'f'),
#             ('F',     'd'),
#             ('F',     'e'),
#             ('F',     'f')],
#            names=['Big', 'Small'])

# %%
df_temp1.index
#最内层索引被移出
# Out:
# Index(['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'], dtype='object', name='Upper')

# %% [markdown]
# ### 4. rename_axis和rename
# #### rename_axis是针对多级索引的方法，作用是修改某一层的索引名，而不是索引标签

# %%
df_temp.rename_axis(index={'Lower':'LowerLower'},columns={'Big':'BigBig'})
# Out:
# BigBig                   D                             E                      \
# Small                    d         e         f         d         e         f
# Upper LowerLower
# A     a           0.322822  0.543179  0.967577  0.888449  0.899564  0.002650
#       b           0.974375  0.433716  0.357654  0.989018  0.389088  0.938990
#       c           0.000210  0.910771  0.786087  0.869291  0.078134  0.251015
# B     a           0.517882  0.447018  0.218146  0.757236  0.887024  0.377133
#       b           0.126310  0.585848  0.060513  0.404525  0.402775  0.002464
#       c           0.857123  0.143604  0.109123  0.282035  0.828932  0.223217
# C     a           0.518320  0.912870  0.965830  0.987105  0.227478  0.854015
#       b           0.509245  0.731148  0.554760  0.528989  0.622561  0.835064
#       c           0.032664  0.455637  0.825416  0.599417  0.603032  0.548469
#
# BigBig                   F
# Small                    d         e         f
# Upper LowerLower
# A     a           0.299921  0.872671  0.268278
#       b           0.905009  0.473362  0.693009
#       c           0.788266  0.707512  0.821467
# B     a           0.004297  0.919222  0.393171
#       b           0.833294  0.619312  0.174691
#       c           0.565387  0.965838  0.205445
# C     a           0.974328  0.612281  0.757832
#       b           0.684865  0.836928  0.663610
#       c           0.697813  0.849007  0.285154

# %% [markdown]
# #### rename方法用于修改列或者行索引标签，而不是索引名：

# %%
df_temp.rename(index={'A':'T'},columns={'e':'changed_e'}).head()
# Out:
# Big                 D                             E                      \
# Small               d changed_e         f         d changed_e         f
# Upper Lower
# T     a      0.322822  0.543179  0.967577  0.888449  0.899564  0.002650
#       b      0.974375  0.433716  0.357654  0.989018  0.389088  0.938990
#       c      0.000210  0.910771  0.786087  0.869291  0.078134  0.251015
# B     a      0.517882  0.447018  0.218146  0.757236  0.887024  0.377133
#       b      0.126310  0.585848  0.060513  0.404525  0.402775  0.002464
#
# Big                 F
# Small               d changed_e         f
# Upper Lower
# T     a      0.299921  0.872671  0.268278
#       b      0.905009  0.473362  0.693009
#       c      0.788266  0.707512  0.821467
# B     a      0.004297  0.919222  0.393171
#       b      0.833294  0.619312  0.174691

# %% [markdown]
# ## 四、常用索引型函数
# ### 1. where函数
# #### 当对条件为False的单元进行填充：

# %%
df.head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %%
df.where(df['Gender']=='M').head()
#不满足条件的行全部被设置为NaN
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1   173.0    63.0  34.0      A+
# 1102    NaN   NaN    NaN       NaN     NaN     NaN   NaN     NaN
# 1103    S_1   C_1      M  street_2   186.0    82.0  87.2      B+
# 1104    NaN   NaN    NaN       NaN     NaN     NaN   NaN     NaN
# 1105    NaN   NaN    NaN       NaN     NaN     NaN   NaN     NaN

# %% [markdown]
# #### 通过这种方法筛选结果和[]操作符的结果完全一致：

# %%
df.where(df['Gender']=='M').dropna().head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1   173.0    63.0  34.0      A+
# 1103    S_1   C_1      M  street_2   186.0    82.0  87.2      B+
# 1201    S_1   C_2      M  street_5   188.0    68.0  97.0      A-
# 1203    S_1   C_2      M  street_6   160.0    53.0  58.8      A+
# 1301    S_1   C_3      M  street_4   161.0    68.0  31.5      B+

# %% [markdown]
# #### 第一个参数为布尔条件，第二个参数为填充值：

# %%
df.where(df['Gender']=='M',np.random.rand(df.shape[0],df.shape[1])).head()
# Out:
#         School     Class    Gender   Address      Height     Weight  \
# ID
# 1101       S_1       C_1         M  street_1  173.000000  63.000000
# 1102  0.923269  0.889968  0.118121  0.769745    0.027177   0.674623
# 1103       S_1       C_1         M  street_2  186.000000  82.000000
# 1104  0.394707   0.40744  0.056946  0.340527    0.120786   0.667857
# 1105  0.885112  0.944421  0.421259  0.915355    0.936984   0.104116
#
#            Math   Physics
# ID
# 1101  34.000000        A+
# 1102   0.146644   0.46533
# 1103  87.200000        B+
# 1104   0.458896  0.000567
# 1105   0.868833  0.393474

# %% [markdown]
# ### 2. mask函数
# #### mask函数与where功能上相反，其余完全一致，即对条件为True的单元进行填充

# %%
df.mask(df['Gender']=='M').dropna().head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2   192.0    73.0  32.5      B+
# 1104    S_1   C_1      F  street_2   167.0    81.0  80.4      B-
# 1105    S_1   C_1      F  street_4   159.0    64.0  84.8      B+
# 1202    S_1   C_2      F  street_4   176.0    94.0  63.5      B-
# 1204    S_1   C_2      F  street_5   162.0    63.0  33.8       B

# %%
df.mask(df['Gender']=='M',np.random.rand(df.shape[0],df.shape[1])).head()
# Out:
#         School     Class    Gender   Address      Height     Weight  \
# ID
# 1101   0.49474  0.116346  0.732123  0.729519    0.367133   0.217317
# 1102       S_1       C_1         F  street_2  192.000000  73.000000
# 1103  0.279154  0.252788  0.577099  0.474547    0.742655   0.055492
# 1104       S_1       C_1         F  street_2  167.000000  81.000000
# 1105       S_1       C_1         F  street_4  159.000000  64.000000
#
#            Math   Physics
# ID
# 1101   0.553423  0.476733
# 1102  32.500000        B+
# 1103   0.842933  0.897562
# 1104  80.400000        B-
# 1105  84.800000        B+

# %% [markdown]
# ### 3. query函数

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# #### query函数中的布尔表达式中，下面的符号都是合法的：行列索引名、字符串、and/not/or/&/|/~/not in/in/==/!=、四则运算符

# %%
df.query('(Address in ["street_6","street_7"]) & (Weight>(70+10)) & (ID in [1303,2304,2402])')
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1303    S_1   C_3      M  street_7     188      82  49.7       B
# 2304    S_2   C_3      F  street_6     164      81  95.5      A-
# 2402    S_2   C_4      M  street_7     166      82  48.7       B

# %% [markdown]
# ## 五、重复元素处理
# ### 1. duplicated方法
# #### 该方法返回了是否重复的布尔列表

# %%
df.duplicated('Class').head()
# Out:
# ID
# 1101    False
# 1102     True
# 1103     True
# 1104     True
# 1105     True
# dtype: bool

# %% [markdown]
# #### 可选参数keep默认为first，即首次出现设为不重复，若为last，则最后一次设为不重复，若为False，则所有重复项为True

# %%
df.duplicated('Class',keep='last').tail()
# Out:
# ID
# 2401     True
# 2402     True
# 2403     True
# 2404     True
# 2405    False
# dtype: bool

# %%
df.duplicated('Class',keep=False).head()
# Out:
# ID
# 1101    True
# 1102    True
# 1103    True
# 1104    True
# 1105    True
# dtype: bool

# %% [markdown]
# ### 2. drop_duplicates方法
# #### 从名字上看出为剔除重复项，这在后面章节中的分组操作中可能是有用的，例如需要保留每组的第一个值：

# %%
df.drop_duplicates('Class')
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1201    S_1   C_2      M  street_5     188      68  97.0      A-
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+
# 2401    S_2   C_4      F  street_2     192      62  45.3       A

# %% [markdown]
# #### 参数与duplicate函数类似：

# %%
df.drop_duplicates('Class',keep='last')
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 2105    S_2   C_1      M  street_4     170      81  34.2       A
# 2205    S_2   C_2      F  street_7     183      76  85.4       B
# 2305    S_2   C_3      M  street_4     187      73  48.9       B
# 2405    S_2   C_4      F  street_6     193      54  47.6       B

# %% [markdown]
# #### 在传入多列时等价于将多列共同视作一个多级索引，比较重复项：

# %%
df.drop_duplicates(['School','Class'])
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1201    S_1   C_2      M  street_5     188      68  97.0      A-
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+
# 2101    S_2   C_1      M  street_7     174      84  83.3       C
# 2201    S_2   C_2      M  street_5     193     100  39.1       B
# 2301    S_2   C_3      F  street_4     157      78  72.3      B+
# 2401    S_2   C_4      F  street_2     192      62  45.3       A

# %% [markdown]
# ## 六、抽样函数
# #### 这里的抽样函数指的就是sample函数
# #### （a）n为样本量

# %%
df.sample(n=5)
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 2103    S_2   C_1      M  street_4     157      61  52.5      B-
# 2201    S_2   C_2      M  street_5     193     100  39.1       B
# 2403    S_2   C_4      F  street_6     158      60  59.7      B+
# 1205    S_1   C_2      F  street_6     167      63  68.4      B-
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+

# %% [markdown]
# #### （b）frac为抽样比

# %%
df.sample(frac=0.05)
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1305    S_1   C_3      F  street_5     187      69  61.7      B-
# 2405    S_2   C_4      F  street_6     193      54  47.6       B

# %% [markdown]
# #### （c）replace为是否放回

# %%
df.sample(n=df.shape[0],replace=True).head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 2202    S_2   C_2      F  street_7     194      77  68.5      B+
# 2102    S_2   C_1      F  street_6     161      61  50.6      B+
# 2204    S_2   C_2      M  street_1     175      74  47.2      B-
# 2404    S_2   C_4      F  street_2     160      84  67.7       B
# 2202    S_2   C_2      F  street_7     194      77  68.5      B+

# %%
df.sample(n=35,replace=True).index.is_unique
# Out:
# False

# %% [markdown]
# #### （d）axis为抽样维度，默认为0，即抽行

# %%
df.sample(n=3,axis=1).head()
# Out:
#      Class  Height Gender
# ID
# 1101   C_1     173      M
# 1102   C_1     192      F
# 1103   C_1     186      M
# 1104   C_1     167      F
# 1105   C_1     159      F

# %% [markdown]
# #### （e）weights为样本权重，自动归一化

# %%
df.sample(n=3,weights=np.random.rand(df.shape[0])).head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 2203    S_2   C_2      M  street_4     155      91  73.8      A+
# 2302    S_2   C_3      M  street_5     171      88  32.7       A
# 1204    S_1   C_2      F  street_5     162      63  33.8       B

# %%
#以某一列为权重，这在抽样理论中很常见
#抽到的概率与Math数值成正比
df.sample(n=3,weights=df['Math']).head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1205    S_1   C_2      F  street_6     167      63  68.4      B-
# 2305    S_2   C_3      M  street_4     187      73  48.9       B
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-

# %% [markdown]
# ## 七、问题与练习

# %% [markdown]
# ### 1. 问题
# #### 【问题一】 如何更改列或行的顺序？如何交换奇偶行（列）的顺序？
# #### 【问题二】 如果要选出DataFrame的某个子集，请给出尽可能多的方法实现。
# #### 【问题三】 query函数比其他索引方法的速度更慢吗？在什么场合使用什么索引最高效？
# #### 【问题四】 单级索引能使用Slice对象吗？能的话怎么使用，请给出一个例子。
# #### 【问题五】 如何快速找出某一列的缺失值所在索引？
# #### 【问题六】 索引设定中的所有方法分别适用于哪些场合？怎么直接把某个DataFrame的索引换成任意给定同长度的索引？
# #### 【问题七】 多级索引有什么适用场合？
# #### 【问题八】 对于多层索引，怎么对内层进行条件筛选？
# #### 【问题九】 什么时候需要重复元素处理？

# %% [markdown]
# ### 2. 练习
# #### 【练习一】 现有一份关于UFO的数据集，请解决下列问题：

# %%
pd.read_csv('data/UFO.csv').head()
# Out:
#            datetime     shape  duration (seconds)   latitude   longitude
# 0  10/10/1949 20:30  cylinder              2700.0  29.883056  -97.941111
# 1  10/10/1949 21:00     light              7200.0  29.384210  -98.581082
# 2  10/10/1955 17:00    circle                20.0  53.200000   -2.916667
# 3  10/10/1956 21:00    circle                20.0  28.978333  -96.645833
# 4  10/10/1960 20:00     light               900.0  21.418056 -157.803611

# %% [markdown]
# #### （a）在所有被观测时间超过60s的时间中，哪个形状最多？

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("data/UFO.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            80332 non-null  object
#  1   shape               78400 non-null  object
#  2   duration (seconds)  80332 non-null  float64
#  3   latitude            80332 non-null  float64
#  4   longitude           80332 non-null  float64
# dtypes: float64(3), object(2)
# memory usage: 3.1+ MB

# %%
df.rename(columns={"duration (seconds)":"duration"}, inplace=True)
df['duration'].astype('float64') # 保证数字类型
df.head()
# Out:
#            datetime     shape  duration   latitude   longitude
# 0  10/10/1949 20:30  cylinder    2700.0  29.883056  -97.941111
# 1  10/10/1949 21:00     light    7200.0  29.384210  -98.581082
# 2  10/10/1955 17:00    circle      20.0  53.200000   -2.916667
# 3  10/10/1956 21:00    circle      20.0  28.978333  -96.645833
# 4  10/10/1960 20:00     light     900.0  21.418056 -157.803611

# %%
df[df['duration']>60]['shape'].value_counts().index[0]
# Out:
# 'light'

# %% [markdown]
# #### （b）对经纬度进行划分：-180°至180°以30°为一个经度划分，-90°至90°以18°为一个纬度划分，请问哪个区域中报告的UFO事件数量最多？

# %%
# 经度 12个区间，13个边界
# 纬度 10个区间，11个边界

bins_long = np.linspace(-180, 180, 13).tolist() # 使用np.linspace() 的小技巧获取
bins_la = np.linspace(-90, 90, 11)
# bins_la = np.arange(-90,90+1, 18).tolist()
bins_la
# Out:
# array([-90., -72., -54., -36., -18.,   0.,  18.,  36.,  54.,  72.,  90.])

# %%
df['cut_long'] = pd.cut(df['longitude'], bins= bins_long)
df['cut_la'] = pd.cut(df['latitude'], bins= bins_la)
df.head()
# Out:
#            datetime     shape  duration (seconds)   latitude   longitude  \
# 0  10/10/1949 20:30  cylinder              2700.0  29.883056  -97.941111
# 1  10/10/1949 21:00     light              7200.0  29.384210  -98.581082
# 2  10/10/1955 17:00    circle                20.0  53.200000   -2.916667
# 3  10/10/1956 21:00    circle                20.0  28.978333  -96.645833
# 4  10/10/1960 20:00     light               900.0  21.418056 -157.803611
#
#            cut_long        cut_la
# 0   (-120.0, -90.0]  (18.0, 36.0]
# 1   (-120.0, -90.0]  (18.0, 36.0]
# 2      (-30.0, 0.0]  (36.0, 54.0]
# 3   (-120.0, -90.0]  (18.0, 36.0]
# 4  (-180.0, -150.0]  (18.0, 36.0]

# %%
df.set_index(['cut_long','cut_la']).index.value_counts()
# Out:
# ((-90.0, -60.0], (36.0, 54.0])        27891
# ((-120.0, -90.0], (18.0, 36.0])       14280
# ((-120.0, -90.0], (36.0, 54.0])       11960
# ((-90.0, -60.0], (18.0, 36.0])         9923
# ((-150.0, -120.0], (36.0, 54.0])       9658
#                                       ...
# ((-180.0, -150.0], (-36.0, -18.0])        1
# ((-150.0, -120.0], (-90.0, -72.0])        1
# ((-120.0, -90.0], (-36.0, -18.0])         1
# ((-180.0, -150.0], (36.0, 54.0])          1
# ((-120.0, -90.0], (-18.0, 0.0])           1
# Length: 65, dtype: int64

# %% [markdown]
# #### 【练习二】 现有一份关于口袋妖怪的数据集，请解决下列问题：

# %%
pd.read_csv('data/Pokemon.csv').head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# #### （a）双属性的Pokemon占总体比例的多少？

# %%
df = pd.read_csv('data/Pokemon.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df['Type 2'].count() /df.shape[0]
# Out:
# 0.5175

# %% [markdown]
# #### （b）在所有种族值（Total）不小于580的Pokemon中，非神兽（Legendary=False）的比例为多少？

# %%
df.query('Total >= 580')['Legendary'].value_counts(normalize=True)
# Out:
# True     0.575221
# False    0.424779
# Name: Legendary, dtype: float64

# %% [markdown]
# #### （c）在第一属性为格斗系（Fighting）的Pokemon中，物攻排名前三高的是哪些？

# %%
df[df['Type 1']=='Fighting'].sort_values(by='Attack', ascending=False).iloc[0:3]
# Out:
#        #                 Name    Type 1 Type 2  Total   HP  Attack  Defense  \
# 498  448  LucarioMega Lucario  Fighting  Steel    625   70     145       88
# 594  534           Conkeldurr  Fighting    NaN    505  105     140       95
# 74    68              Machamp  Fighting    NaN    505   90     130       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 498      140       70    112           4      False
# 594       55       65     45           5      False
# 74        65       85     55           1      False

# %% [markdown]
# #### （d）请问六项种族指标（HP、物攻、特攻、物防、特防、速度）极差的均值最大的是哪个属性（只考虑第一属性，且均值是对属性而言）？

# %%
df['range'] = df.iloc[:, 5:11].max(axis=1) - df.iloc[:, 5:11].min(axis=1)
attribute = df[['Type 1', 'range']].set_index('Type 1')
max_range = 0
res = ''
for i in attribute.index.unique():
    temp = attribute.loc[i, :].mean()
    if temp.values[0] > max_range:
        max_range = temp.values[0]
        res = i
res
# Out:
# 'Steel'

# %%
[temp.values][0]
# Out:
# array([43.75])

# %% [markdown]
# #### （e）哪个属性（只考虑第一属性）神兽占总Pokemon的比例最高？该属性神兽的种族值也是最高的吗？

# %%
df[df['Legendary']==True]['Type 1'].value_counts(normalize=True).index[0]
# Out:
# 'Psychic'

# %%
attribute = df[df['Legendary']==True][['Type 1', 'Total']].set_index('Type 1')

max_value = 0
res = ''

for i in attribute.index.unique()[0:-1]: # 最后一个类型不要
    temp = attribute.loc[i,:].mean()
    print(type(temp))
    if max_value < temp[0]:
        max_value = temp[0]
        res = i

res
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# 'Normal'

# %%
attribute.index.unique()[0:-1]
attribute.index.unique()
# Out:
# Index(['Ice', 'Electric', 'Fire', 'Psychic', 'Water', 'Rock', 'Steel',
#        'Dragon', 'Ground', 'Normal', 'Ghost', 'Dark', 'Grass', 'Flying',
#        'Fairy'],
#       dtype='object', name='Type 1')
